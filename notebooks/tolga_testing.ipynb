# %%
import sys
sys.path.append('../')
sys.path.append('./')

import seisbench.models as sbm

from classification.eqt import EQTHandler
from classification.phasenet import PhaseNetHandler
from utils import utils

import matplotlib.pyplot as plt 
import scipy.signal as signal

# %%
# Original: N, P, S
# Stead: P, S, N
handler = PhaseNetHandler()
train, test, y_train, y_test = utils.load_dataset_from_disk("../data/STEAD/chunk2/merged.csv", "../data/STEAD/chunk2/merged.hdf5", frac=0.0001)
handler.plot_preds(train, y_train, model_type="original")
# Out:
# c:\Users\tolga\Documents\Uni\DSLab\earthquake-monitoring\notebooks\..\utils\utils.py:17: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   metadata = pd.read_csv(metadata_path)
